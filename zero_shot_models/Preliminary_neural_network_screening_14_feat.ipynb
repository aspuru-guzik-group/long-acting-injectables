# %% [markdown]
# ### Deployed in Colabs with TPU accelerator

# %%
# Connect to GDrive

import gc
import pickle
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# import the necessary libraries to execute this code
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold, GroupShuffleSplit
from sklearn.model_selection import RandomizedSearchCV as RSCV

# build NN for class
from tensorflow.keras.layers import  Dropout
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Dense,Dropout
import tensorflow
from tensorflow import keras

# %%
# create a function that will build and compile a Keras model

def NN_builder(n_hidden=1, optimizer = 'rmsprop', units=40, learning_rate = 0.001, input_shape=[14], 
               regularization=0.001, dropout=0.2, activation = 'sigmoid'):
    model = keras.models.Sequential()
    model.add(keras.layers.InputLayer(input_shape=input_shape))
  
    for layer in range (n_hidden):
        model.add(keras.layers.Dense(units=40, activation=activation, activity_regularizer=l1_l2(regularization)))
        model.add(Dropout(dropout))
  
    model.add(keras.layers.Dense(units=1,activation='sigmoid'))
    optimizer = keras.optimizers.RMSprop(learning_rate=learning_rate)

    model.compile(loss="mean_absolute_error", optimizer=optimizer)
    return model

NN = tensorflow.keras.wrappers.scikit_learn.KerasRegressor(NN_builder)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.

# %%
datafile = "/content/Dataset_14_feat.xlsx"
df = pd.read_excel(datafile)

model = NN
p_grid ={"n_hidden" : [1,2,3,4,5],
         "units" : [10,20,30,40,50],
         "learning_rate": [0.0001,0.001,0.01],
         "regularization":[1e-2,1e-3,1e-4],
         "dropout":[0.0,0.1,0.2,0.3],
         "batch_size":[32, 64, 128, 256],
         "activation": ['relu', 'tanh', 'sigmoid']}

X = df.drop(['Experimental_index','DP_Group','Release'],axis='columns')
stdScale = StandardScaler().fit(X)
X=stdScale.transform(X)
Y = df['Release']
G = df['DP_Group']
E = df['Experimental_index']
T = df['Time']

# %%
# Number of epochs
epochs = 50

# Define callaback
callbacks=[keras.callbacks.EarlyStopping(monitor='loss', patience=5)]

NUM_TRIALS = 10

itr_number = [] # create new empty list for itr number 
outer_results = []
inner_results = []
model_params = []
G_test_list = []
y_test_list = []
E_test_list = []
T_test_list = []
pred_list = []
pred_var_list = []

for i in range(NUM_TRIALS): #configure the cross-validation procedure - outer loop (test set) 

      cv_outer = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=i) #hold back 20% of the groups for test set

      # split data using GSS
      for train_index, test_index in cv_outer.split(X, Y, G):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = Y[train_index], Y[test_index]
        G_train, G_test = G[train_index], G[test_index]
        E_train, E_test = E[train_index], E[test_index]
        T_train, T_test = T[train_index], T[test_index]

        # store test set information
        G_test = np.array(G_test) #prevents index from being brought from dataframe
        G_test_list.append(G_test)
        E_test = np.array(E_test) #prevents index from being brought from dataframe
        E_test_list.append(E_test)
        T_test = np.array(T_test) #prevents index from being brought from dataframe
        T_test_list.append(T_test)
        y_test = np.array(y_test) #prevents index from being brought from dataframe
        y_test_list.append(y_test)

        # configure the cross-validation procedure - inner loop (validation set/HP optimization)
        cv_inner = GroupKFold(n_splits=10) #should be 10 fold group split for inner loop

        # define search space
        search = RSCV(model, p_grid, n_iter=50, verbose=3, scoring='neg_mean_absolute_error', cv=cv_inner, refit=True) # should be 100

        # execute search
        result = search.fit(X_train, y_train, groups=G_train, callbacks=callbacks, epochs=epochs, verbose=0)

        # get the best performing model fit on the whole training set
        best_model = result.best_estimator_

        # get the score for the best performing model and store
        best_score = abs(result.best_score_)
        inner_results.append(best_score)

        # evaluate model and estimate epistemic uncertainty on the hold out dataset
        predictions = []
        for _ in range(100):
            predictions += [best_model.predict(X_test, verbose=0)]
        
        yhat, pred_unbiased = np.mean(np.array(predictions), axis=0), np.std(np.array(predictions), axis=0)

        # store drug release predictions
        pred_list.append(yhat)
            
        # store prediction variance
        pred_var_list.append(pred_unbiased)

        # evaluate the model
        acc = mean_absolute_error(y_test, yhat)

        # store the result
        itr_number.append(i+1)
        outer_results.append(acc)
        model_params.append(result.best_params_)

      # report progress at end of each inner loop
      print('\n################################################################\n\nSTATUS REPORT:') 
      print('Iteration '+str(i+1)+' of '+str(NUM_TRIALS)+' runs completed') 
      print('Test_Score: %.3f, Best_Valid_Score: %.3f, \n\nBest_Model_Params: \n%s' % (acc, best_score, result.best_params_))
      print("\n################################################################\n ")
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [CV 1/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.001, units=50;, score=-0.286 total time=   2.4s
# [CV 2/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.001, units=50;, score=-0.260 total time=   3.5s
# [CV 3/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.001, units=50;, score=-0.262 total time=   2.5s
# [CV 4/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.001, units=50;, score=-0.187 total time=   3.3s
# WARNING:tensorflow:5 out of the last 19 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd2a8a60cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [CV 5/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.001, units=50;, score=-0.314 total time=   2.6s
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd2ae071dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Streaming output truncated to the last 5000 lines.
# [CV 10/10] END activation=sigmoid, batch_size=256, dropout=0.3, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=20;, score=-0.339 total time=   3.8s
# [CV 1/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.257 total time=   2.5s
# [CV 2/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.215 total time=   3.4s
# [CV 3/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.220 total time=   2.8s
# [CV 4/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.247 total time=   3.4s
# [CV 5/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.195 total time=   3.4s
# [CV 6/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.142 total time=   2.4s
# [CV 7/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.158 total time=   2.8s
# [CV 8/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.282 total time=   3.5s
# [CV 9/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.268 total time=   2.4s
# [CV 10/10] END activation=relu, batch_size=128, dropout=0.0, learning_rate=0.01, n_hidden=2, regularization=0.0001, units=10;, score=-0.218 total time=   3.4s
# [CV 1/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.239 total time=   6.3s
# [CV 2/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.230 total time=  11.0s
# [CV 3/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.193 total time=   6.8s
# [CV 4/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.204 total time=  10.9s
# [CV 5/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.176 total time=   6.7s
# [CV 6/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.112 total time=  10.9s
# [CV 7/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.152 total time=   6.8s
# [CV 8/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.197 total time=  10.9s
# [CV 9/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.298 total time=  10.9s
# [CV 10/10] END activation=sigmoid, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.001, units=50;, score=-0.210 total time=  11.0s
# [CV 1/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.233 total time=   3.2s
# [CV 2/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.180 total time=   4.2s
# [CV 3/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.209 total time=   3.7s
# [CV 4/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.143 total time=   3.8s
# [CV 5/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.226 total time=   3.8s
# [CV 6/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.157 total time=   3.9s
# [CV 7/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.208 total time=   4.3s
# [CV 8/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.242 total time=   3.9s
# [CV 9/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.348 total time=   3.1s
# [CV 10/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=30;, score=-0.196 total time=   3.8s
# [CV 1/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.255 total time=   5.8s
# [CV 2/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.284 total time=  10.9s
# [CV 3/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.235 total time=   7.1s
# [CV 4/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.422 total time=  11.0s
# [CV 5/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.157 total time=  10.9s
# [CV 6/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.128 total time=  10.9s
# [CV 7/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.194 total time=  10.9s
# [CV 8/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.261 total time=   6.6s
# [CV 9/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.384 total time=   6.7s
# [CV 10/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.001, n_hidden=1, regularization=0.01, units=10;, score=-0.140 total time=  10.9s
# [CV 1/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.263 total time=   4.7s
# [CV 2/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.232 total time=   5.9s
# [CV 3/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.258 total time=   7.2s
# [CV 4/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.169 total time=   6.7s
# [CV 5/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.161 total time=   5.8s
# [CV 6/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.159 total time=   6.0s
# [CV 7/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.185 total time=   5.8s
# [CV 8/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.205 total time=   6.3s
# [CV 9/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.341 total time=   5.9s
# [CV 10/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.001, n_hidden=5, regularization=0.0001, units=50;, score=-0.165 total time=   5.8s
# [CV 1/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.272 total time=   6.5s
# [CV 2/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.276 total time=  11.4s
# [CV 3/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.281 total time=   8.1s
# [CV 4/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.285 total time=  11.4s
# [CV 5/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.257 total time=  11.8s
# [CV 6/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.114 total time=   8.3s
# [CV 7/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.159 total time=   8.1s
# [CV 8/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.334 total time=  11.4s
# [CV 9/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.250 total time=  11.4s
# [CV 10/10] END activation=relu, batch_size=32, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.146 total time=   8.1s
# [CV 1/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.306 total time=   2.0s
# [CV 2/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.300 total time=   1.7s
# [CV 3/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.268 total time=   2.0s
# [CV 4/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.226 total time=   2.0s
# [CV 5/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.328 total time=   2.1s
# [CV 6/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.264 total time=   1.7s
# [CV 7/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.263 total time=   1.7s
# [CV 8/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.264 total time=   1.7s
# [CV 9/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.341 total time=   2.0s
# [CV 10/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=30;, score=-0.314 total time=   2.0s
# [CV 1/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.311 total time=   2.8s
# [CV 2/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.235 total time=   3.2s
# [CV 3/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.225 total time=   3.2s
# [CV 4/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.363 total time=   4.5s
# [CV 5/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.233 total time=   4.0s
# [CV 6/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.108 total time=   3.4s
# [CV 7/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.197 total time=   3.3s
# [CV 8/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.198 total time=   3.2s
# [CV 9/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.288 total time=   3.5s
# [CV 10/10] END activation=sigmoid, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=4, regularization=0.01, units=30;, score=-0.253 total time=   4.1s
# [CV 1/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.269 total time=   1.9s
# [CV 2/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.251 total time=   2.4s
# [CV 3/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.227 total time=   1.9s
# [CV 4/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.195 total time=   2.4s
# [CV 5/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.261 total time=   2.4s
# [CV 6/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.123 total time=   2.5s
# [CV 7/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.178 total time=   2.9s
# [CV 8/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.336 total time=   2.5s
# [CV 9/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.366 total time=   2.4s
# [CV 10/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=10;, score=-0.238 total time=   2.5s
# [CV 1/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.200 total time=   6.6s
# [CV 2/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.253 total time=   6.6s
# [CV 3/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.242 total time=   6.1s
# [CV 4/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.213 total time=   5.9s
# [CV 5/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.259 total time=   6.6s
# [CV 6/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.175 total time=   6.6s
# [CV 7/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.188 total time=   6.6s
# [CV 8/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.227 total time=   6.6s
# [CV 9/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.298 total time=   6.3s
# [CV 10/10] END activation=tanh, batch_size=64, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.0001, units=10;, score=-0.255 total time=   6.0s
# [CV 1/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.232 total time=   6.5s
# [CV 2/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.270 total time=   6.5s
# [CV 3/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.274 total time=   5.4s
# [CV 4/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.353 total time=   6.5s
# [CV 5/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.276 total time=   6.9s
# [CV 6/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.193 total time=   5.2s
# [CV 7/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.200 total time=   5.5s
# [CV 8/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.314 total time=   6.5s
# [CV 9/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.408 total time=   5.4s
# [CV 10/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=50;, score=-0.213 total time=   6.5s
# [CV 1/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.202 total time=   6.3s
# [CV 2/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.272 total time=   5.2s
# [CV 3/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.240 total time=   6.3s
# [CV 4/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.365 total time=   6.3s
# [CV 5/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.289 total time=   4.8s
# [CV 6/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.179 total time=   4.7s
# [CV 7/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.180 total time=   4.8s
# [CV 8/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.265 total time=   4.8s
# [CV 9/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.287 total time=   6.7s
# [CV 10/10] END activation=tanh, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.01, units=30;, score=-0.252 total time=   6.3s
# [CV 1/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.177 total time=   3.3s
# [CV 2/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.259 total time=   2.4s
# [CV 3/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.251 total time=   3.3s
# [CV 4/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.153 total time=   2.4s
# [CV 5/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.269 total time=   3.3s
# [CV 6/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.185 total time=   2.4s
# [CV 7/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.220 total time=   3.3s
# [CV 8/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.244 total time=   2.3s
# [CV 9/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.294 total time=   3.3s
# [CV 10/10] END activation=tanh, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=1, regularization=0.01, units=20;, score=-0.268 total time=   3.2s
# [CV 1/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.195 total time=   3.9s
# [CV 2/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.283 total time=   4.3s
# [CV 3/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.279 total time=   4.3s
# [CV 4/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.438 total time=   6.0s
# [CV 5/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.211 total time=   4.4s
# [CV 6/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.127 total time=   6.0s
# [CV 7/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.187 total time=   6.0s
# [CV 8/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.191 total time=   4.3s
# [CV 9/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.253 total time=   6.0s
# [CV 10/10] END activation=relu, batch_size=64, dropout=0.0, learning_rate=0.0001, n_hidden=2, regularization=0.001, units=20;, score=-0.202 total time=   6.4s
# [CV 1/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.219 total time=   6.3s
# [CV 2/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.370 total time=   6.3s
# [CV 3/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.175 total time=   5.1s
# [CV 4/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.177 total time=   6.4s
# [CV 5/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.231 total time=   6.3s
# [CV 6/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.145 total time=   6.3s
# [CV 7/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.142 total time=   6.3s
# [CV 8/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.295 total time=   5.5s
# [CV 9/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.283 total time=   6.3s
# [CV 10/10] END activation=relu, batch_size=64, dropout=0.1, learning_rate=0.001, n_hidden=3, regularization=0.01, units=40;, score=-0.233 total time=   6.3s
# [CV 1/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.274 total time=   2.4s
# [CV 2/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.312 total time=   2.4s
# [CV 3/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.279 total time=   2.3s
# [CV 4/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.281 total time=   2.4s
# [CV 5/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.327 total time=   2.7s
# [CV 6/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.278 total time=   2.3s
# [CV 7/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.286 total time=   2.4s
# [CV 8/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.260 total time=   2.5s
# [CV 9/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.348 total time=   2.4s
# [CV 10/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.0001, units=50;, score=-0.338 total time=   2.4s
# [CV 1/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.264 total time=  11.8s
# [CV 2/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.313 total time=   9.1s
# [CV 3/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.280 total time=  12.2s
# [CV 4/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.247 total time=  11.7s
# [CV 5/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.325 total time=  11.7s
# [CV 6/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.275 total time=   9.4s
# [CV 7/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.286 total time=  11.7s
# [CV 8/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.261 total time=   9.0s
# [CV 9/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.348 total time=   9.5s
# [CV 10/10] END activation=sigmoid, batch_size=32, dropout=0.2, learning_rate=0.0001, n_hidden=4, regularization=0.01, units=40;, score=-0.335 total time=   9.2s
# [CV 1/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.286 total time=   1.3s
# [CV 2/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.318 total time=   1.4s
# [CV 3/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.262 total time=   2.0s
# [CV 4/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.278 total time=   2.0s
# [CV 5/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.216 total time=   1.5s
# [CV 6/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.099 total time=   1.3s
# [CV 7/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.156 total time=   2.0s
# [CV 8/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.198 total time=   1.1s
# [CV 9/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.331 total time=   2.4s
# [CV 10/10] END activation=relu, batch_size=256, dropout=0.1, learning_rate=0.01, n_hidden=1, regularization=0.0001, units=10;, score=-0.173 total time=   1.7s
# [CV 1/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.205 total time=   4.3s
# [CV 2/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.276 total time=   4.8s
# [CV 3/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.252 total time=   4.7s
# [CV 4/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.292 total time=   4.7s
# [CV 5/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.327 total time=   5.3s
# [CV 6/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.242 total time=   6.8s
# [CV 7/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.230 total time=   5.0s
# [CV 8/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.289 total time=   5.0s
# [CV 9/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.311 total time=   5.0s
# [CV 10/10] END activation=relu, batch_size=128, dropout=0.2, learning_rate=0.0001, n_hidden=5, regularization=0.001, units=40;, score=-0.303 total time=   4.6s
# [CV 1/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.226 total time=   3.3s
# [CV 2/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.313 total time=   2.2s
# [CV 3/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.279 total time=   2.2s
# [CV 4/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.287 total time=   2.9s
# [CV 5/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.327 total time=   2.2s
# [CV 6/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.278 total time=   2.4s
# [CV 7/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.287 total time=   2.2s
# [CV 8/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.261 total time=   2.2s
# [CV 9/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.349 total time=   2.2s
# [CV 10/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.01, n_hidden=5, regularization=0.01, units=20;, score=-0.340 total time=   2.2s
# [CV 1/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.249 total time=   2.6s
# [CV 2/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.292 total time=   4.3s
# [CV 3/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.271 total time=   2.7s
# [CV 4/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.237 total time=   3.9s
# [CV 5/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.296 total time=   4.0s
# [CV 6/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.237 total time=   2.7s
# [CV 7/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.218 total time=   2.6s
# [CV 8/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.282 total time=   2.7s
# [CV 9/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.308 total time=   3.2s
# [CV 10/10] END activation=relu, batch_size=256, dropout=0.0, learning_rate=0.0001, n_hidden=4, regularization=0.001, units=20;, score=-0.251 total time=   3.9s
# [CV 1/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.203 total time=   2.2s
# [CV 2/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.250 total time=   3.5s
# [CV 3/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.217 total time=   2.6s
# [CV 4/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.174 total time=   3.8s
# [CV 5/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.212 total time=   3.7s
# [CV 6/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.097 total time=   4.3s
# [CV 7/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.196 total time=   2.5s
# [CV 8/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.217 total time=   3.4s
# [CV 9/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.342 total time=   2.5s
# [CV 10/10] END activation=tanh, batch_size=64, dropout=0.3, learning_rate=0.01, n_hidden=3, regularization=0.001, units=20;, score=-0.239 total time=   2.7s
# [CV 1/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.234 total time=   2.2s
# [CV 2/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.270 total time=   1.9s
# [CV 3/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.226 total time=   2.2s
# [CV 4/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.184 total time=   1.9s
# [CV 5/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.198 total time=   2.4s
# [CV 6/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.164 total time=   2.0s
# [CV 7/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.194 total time=   2.0s
# [CV 8/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.192 total time=   2.2s
# [CV 9/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.277 total time=   2.2s
# [CV 10/10] END activation=tanh, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=2, regularization=0.01, units=50;, score=-0.243 total time=   2.0s
# [CV 1/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.171 total time=   5.5s
# [CV 2/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.259 total time=   7.2s
# [CV 3/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.245 total time=   7.0s
# [CV 4/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.165 total time=   6.9s
# [CV 5/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.283 total time=  11.4s
# [CV 6/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.203 total time=   6.8s
# [CV 7/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.211 total time=  10.9s
# [CV 8/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.283 total time=  10.9s
# [CV 9/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.274 total time=  11.0s
# [CV 10/10] END activation=sigmoid, batch_size=32, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=50;, score=-0.254 total time=   7.0s
# [CV 1/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.262 total time=   2.4s
# [CV 2/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.290 total time=   2.3s
# [CV 3/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.274 total time=   2.2s
# [CV 4/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.498 total time=   2.4s
# [CV 5/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.333 total time=   2.8s
# [CV 6/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.179 total time=   2.4s
# [CV 7/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.208 total time=   2.4s
# [CV 8/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.281 total time=   2.4s
# [CV 9/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.291 total time=   2.4s
# [CV 10/10] END activation=sigmoid, batch_size=256, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.01, units=50;, score=-0.282 total time=   2.4s
# [CV 1/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.235 total time=   3.3s
# [CV 2/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.249 total time=   3.9s
# [CV 3/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.207 total time=   5.8s
# [CV 4/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.165 total time=   6.3s
# [CV 5/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.215 total time=   3.9s
# [CV 6/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.115 total time=   5.8s
# [CV 7/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.157 total time=   3.9s
# [CV 8/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.168 total time=   3.9s
# [CV 9/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.288 total time=   4.0s
# [CV 10/10] END activation=sigmoid, batch_size=64, dropout=0.3, learning_rate=0.001, n_hidden=1, regularization=0.001, units=40;, score=-0.218 total time=   5.8s
# [CV 1/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.208 total time=   8.3s
# [CV 2/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.260 total time=  12.0s
# [CV 3/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.219 total time=  12.4s
# [CV 4/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.192 total time=  10.6s
# [CV 5/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.251 total time=  10.5s
# [CV 6/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.132 total time=  11.9s
# [CV 7/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.205 total time=   9.8s
# [CV 8/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.202 total time=  12.5s
# [CV 9/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.334 total time=  10.7s
# [CV 10/10] END activation=tanh, batch_size=32, dropout=0.2, learning_rate=0.001, n_hidden=5, regularization=0.01, units=20;, score=-0.254 total time=  10.3s
# [CV 1/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.184 total time=   3.3s
# [CV 2/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.257 total time=   3.3s
# [CV 3/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.274 total time=   3.3s
# [CV 4/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.220 total time=   2.4s
# [CV 5/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.297 total time=   3.3s
# [CV 6/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.232 total time=   3.2s
# [CV 7/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.228 total time=   2.5s
# [CV 8/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.257 total time=   3.7s
# [CV 9/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.337 total time=   2.5s
# [CV 10/10] END activation=relu, batch_size=128, dropout=0.1, learning_rate=0.0001, n_hidden=1, regularization=0.0001, units=20;, score=-0.272 total time=   3.3s
# [CV 1/10] END activation=relu, batch_size=32, dropout=0.2, learning_rate=0.01, n_hidden=2, regularization=0.01, units=50;, score=-0.170 total time=   3.5s
# [CV 2/10] END activation=relu, batch_size=32, dropout=0.2, learning_rate=0.01, n_hidden=2, regularization=0.01, units=50;, score=-0.299 total time=   6.0s
# [CV 3/10] END activation=relu, batch_size=32, dropout=0.2, learning_rate=0.01, n_hidden=2, regularization=0.01, units=50;, score=-0.231 total time=   6.1s
# [CV 4/10] END activation=relu, batch_size=32, dropout=0.2, learning_rate=0.01, n_hidden=2, regularization=0.01, units=50;, score=-0.303 total time=   4.2s
# [CV 5/10] END activation=relu, batch_size=32, dropout=0.2, learning_rate=0.01, n_hidden=2, regularization=0.01, units=50;, score=-0.278 total time=   3.7s
# [CV 6/10] END activation=relu, batch_size=32, dropout=0.2, learning_rate=0.01, n_hidden=2, regularization=0.01, units=50;, score=-0.101 total time=   6.1s
# ...
# [CV 3/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.168 total time=   8.4s
# [CV 4/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.112 total time=  12.0s
# [CV 5/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.160 total time=  12.8s
# [CV 6/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.392 total time=  12.0s
# [CV 7/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.140 total time=  12.0s
# [CV 8/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.169 total time=   9.5s
# [CV 9/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.160 total time=   9.0s
# [CV 10/10] END activation=relu, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=5, regularization=0.001, units=20;, score=-0.311 total time=  12.1s
# [CV 1/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.211 total time=   1.8s
# [CV 2/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.215 total time=   2.3s
# [CV 3/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.165 total time=   2.3s
# [CV 4/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.130 total time=   3.0s
# [CV 5/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.213 total time=   2.0s
# [CV 6/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.320 total time=   2.3s
# [CV 7/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.160 total time=   2.0s
# [CV 8/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.304 total time=   2.3s
# [CV 9/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.187 total time=   2.2s
# [CV 10/10] END activation=tanh, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=2, regularization=0.001, units=10;, score=-0.215 total time=   2.2s
# [CV 1/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.190 total time=   3.7s
# [CV 2/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.229 total time=   3.7s
# [CV 3/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.134 total time=   3.7s
# [CV 4/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.170 total time=   2.9s
# [CV 5/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.247 total time=   3.7s
# [CV 6/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.400 total time=   3.6s
# [CV 7/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.171 total time=   3.7s
# [CV 8/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.303 total time=   2.8s
# [CV 9/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.147 total time=   3.7s
# [CV 10/10] END activation=tanh, batch_size=128, dropout=0.0, learning_rate=0.0001, n_hidden=3, regularization=0.001, units=40;, score=-0.263 total time=   3.7s
# [CV 1/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.215 total time=   5.9s
# [CV 2/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.183 total time=  11.0s
# [CV 3/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.170 total time=   4.2s
# [CV 4/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.119 total time=   6.1s
# [CV 5/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.207 total time=  11.0s
# [CV 6/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.344 total time=  11.0s
# [CV 7/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.151 total time=  11.0s
# [CV 8/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.283 total time=   6.2s
# [CV 9/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.179 total time=   5.9s
# [CV 10/10] END activation=tanh, batch_size=32, dropout=0.1, learning_rate=0.001, n_hidden=1, regularization=0.01, units=50;, score=-0.207 total time=  11.0s
# [CV 1/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.149 total time=   3.8s
# [CV 2/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.242 total time=   3.4s
# [CV 3/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.148 total time=   3.5s
# [CV 4/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.114 total time=   3.5s
# [CV 5/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.175 total time=   3.4s
# [CV 6/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.321 total time=   3.4s
# [CV 7/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.123 total time=   3.5s
# [CV 8/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.216 total time=   4.2s
# [CV 9/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.115 total time=   3.4s
# [CV 10/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.001, n_hidden=5, regularization=0.001, units=10;, score=-0.293 total time=   3.5s
# [CV 1/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.225 total time=   2.3s
# [CV 2/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.263 total time=   3.6s
# [CV 3/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.199 total time=   2.8s
# [CV 4/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.174 total time=   3.5s
# [CV 5/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.196 total time=   2.8s
# [CV 6/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.325 total time=   2.7s
# [CV 7/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.166 total time=   3.5s
# [CV 8/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.308 total time=   3.5s
# [CV 9/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.119 total time=   4.3s
# [CV 10/10] END activation=sigmoid, batch_size=128, dropout=0.2, learning_rate=0.001, n_hidden=2, regularization=0.01, units=20;, score=-0.236 total time=   2.8s
# [CV 1/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.254 total time=   4.3s
# [CV 2/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.180 total time=   4.3s
# [CV 3/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.164 total time=   3.0s
# [CV 4/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.116 total time=   3.1s
# [CV 5/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.290 total time=   4.3s
# [CV 6/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.369 total time=   4.3s
# [CV 7/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.186 total time=   4.7s
# [CV 8/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.296 total time=   3.0s
# [CV 9/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.137 total time=   3.0s
# [CV 10/10] END activation=tanh, batch_size=128, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.001, units=20;, score=-0.226 total time=   3.2s
# [CV 1/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.209 total time=   3.7s
# [CV 2/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.205 total time=   2.9s
# [CV 3/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.178 total time=   3.7s
# [CV 4/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.108 total time=   3.7s
# [CV 5/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.175 total time=   2.9s
# [CV 6/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.310 total time=   3.7s
# [CV 7/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.113 total time=   4.4s
# [CV 8/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.298 total time=   3.7s
# [CV 9/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.106 total time=   2.9s
# [CV 10/10] END activation=sigmoid, batch_size=128, dropout=0.0, learning_rate=0.001, n_hidden=3, regularization=0.0001, units=40;, score=-0.222 total time=   3.7s
# [CV 1/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.202 total time=   5.3s
# [CV 2/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.237 total time=   6.8s
# [CV 3/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.127 total time=   7.0s
# [CV 4/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.154 total time=   6.9s
# [CV 5/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.220 total time=  11.2s
# [CV 6/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.343 total time=   7.1s
# [CV 7/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.193 total time=  11.4s
# [CV 8/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.301 total time=   7.0s
# [CV 9/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.181 total time=   7.6s
# [CV 10/10] END activation=tanh, batch_size=32, dropout=0.3, learning_rate=0.0001, n_hidden=2, regularization=0.0001, units=30;, score=-0.207 total time=   6.9s
# [CV 1/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.285 total time=   2.4s
# [CV 2/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.283 total time=   2.4s
# [CV 3/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.309 total time=   2.4s
# [CV 4/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.256 total time=   2.4s
# [CV 5/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.226 total time=   2.3s
# [CV 6/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.322 total time=   3.0s
# [CV 7/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.380 total time=   3.1s
# [CV 8/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.308 total time=   3.0s
# [CV 9/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.349 total time=   2.3s
# [CV 10/10] END activation=relu, batch_size=256, dropout=0.3, learning_rate=0.01, n_hidden=5, regularization=0.01, units=10;, score=-0.282 total time=   2.3s
#
# ################################################################
#
# STATUS REPORT:
# Iteration 10 of 10 runs completed
# Test_Score: 0.312, Best_Valid_Score: 0.161,
#
# Best_Model_Params:
# {'units': 40, 'regularization': 0.0001, 'n_hidden': 2, 'learning_rate': 0.01, 'dropout': 0.2, 'batch_size': 256, 'activation': 'relu'}
#
# ################################################################

# %%
#create dataframe with results of nested CV
list_of_tuples = list(zip(itr_number, inner_results, outer_results, model_params, G_test_list, E_test_list, T_test_list, y_test_list, pred_list, pred_var_list))
CV_dataset = pd.DataFrame(list_of_tuples, columns = ['Iter', 'Valid Score', 'Test Score', 'Model Parms', 'DP_Groups', "Experimental Index", "Time", 'Experimental_Release', 'Predicted_Release','Prediction_Variance'])
CV_dataset['Score_difference'] = abs(CV_dataset['Valid Score'] - CV_dataset['Test Score']) #Groupby dataframe model iterations that best fit the data (i.e., validitaion <= test)
CV_dataset.sort_values(by=['Score_difference', 'Test Score'], ascending=True, inplace=True) 
CV_dataset = CV_dataset.reset_index(drop=True) # Reset index of dataframe
CV_dataset.to_pickle("drive/My Drive/zero_shot_14_feat_NN.pkl") # save dataframe as pickle file

# %%
import pickle
# assign the best model paramaters
best_model_params = CV_dataset.iloc[0,3]
# set params from the best model to a class object
best_model = model.set_params(**best_model_params)
best_model = best_model.fit(X, Y)
with open('drive/My Drive/zero_shot_14_feat_NN_model.pkl', 'wb') as file: # Save the Model to pickle file
          pickle.dump(best_model, file)
# Out:
# 15/15 [==============================] - 1s 3ms/step - loss: 0.3179

# %%
CV_dataset.describe()
# Out:
#            Iter  Valid Score  Test Score  Score_difference
# count  10.00000    10.000000   10.000000         10.000000
# mean    5.50000     0.199359    0.220878          0.036656
# std     3.02765     0.016593    0.041411          0.044351
# min     1.00000     0.160964    0.168039          0.002012
# 25%     3.25000     0.193094    0.203141          0.012898
# 50%     5.50000     0.200395    0.214897          0.024720
# 75%     7.75000     0.210006    0.232844          0.032439
# max    10.00000     0.217717    0.312406          0.151442
